# %% [markdown]
# # Holmes Inspect API Test
# Use this notebook to validate your new `hm.inspect(df)` API on a realistic missingness dataset.

# %%
import pandas as pd
import holmes as hm
# Build a sample dataset with realistic missing-value behavior
n = 40
sample_df = pd.DataFrame({
    "customer_id": list(range(1001, 1001 + n)),
    "country": ["US", "DE", "FR", "BR", "IN"] * 8,
    "age": [
        24, 29, None, 31, 42,
        35, None, 28, 39, 26,
        44, 30, 27, None, 33,
        41, 25, 38, None, 36,
        29, 34, 32, 45, None,
        27, 37, 31, 40, 28,
        None, 26, 35, 39, 30,
        43, None, 33, 41, 29,
    ],
    "salary": [
        None, None, None, 62000, None,
        None, None, None, 58000, None,
        None, None, None, 61000, None,
        None, None, None, 60500, None,
        None, None, None, 59000, None,
        None, None, None, 64000, None,
        None, None, None, 60000, None,
        None, None, None, 61500, None,
    ],
    "segment": ["A", "B", "A", "C"] * 10,
    "last_purchase_days": [
        3, 7, 14, None, 10,
        5, 21, 8, 30, None,
        12, 17, 6, 9, 13,
        None, 20, 11, 15, 18,
        4, None, 22, 16, 19,
        2, 25, 27, None, 24,
        26, 23, 29, 28, None,
        1, 32, 31, 33, 34,
    ],
})

sample_df.head()

dataset = hm.dataset(sample_df)
# Out:
# Traceback (most recent call last):
#
#   File ~/Desktop/holmes/venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 2
#     import holmes as hm
#
#   File ~/Desktop/holmes/holmes/__init__.py:6
#     from api.dataset import Dataset
#
#   File ~/Desktop/holmes/api/__init__.py:1
#     from api.dataset import Dataset
#
#   File ~/Desktop/holmes/api/dataset.py:8
#     from core.service import AnalysisRequest, HolmesService
#
#   File ~/Desktop/holmes/core/service.py:51
#     if s
#         ^
# SyntaxError: expected ':'

# %%
dataset.missing_rates(scope = ['column','row'])
# Out:
# AnalysisRequest(analyzer_id='dataset.missing_rates', inputs={'dataset': 'f30592e0-f06e-4f1f-bce4-ff01b47438b4'}, parameters={'capabilities': {<MissingnessScope.COLUMN: 'column'>, <MissingnessScope.ROW: 'row'>}})
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/holmes/core/analyzer/registry.py:22, in AnalyzerRegistry.get(self, id)
#      21 try :
# ---> 22     return self.items[id]
#      23 except KeyError:
#
# KeyError: 'dataset.missing_rates'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dataset.missing_rates(scope = ['column','row'])
#
# File ~/Desktop/holmes/api/dataset.py:77, in Dataset.missing_rates(self, scope)
#      75 request = self._request_resolver.resolve_missingness(self.id ,scope)
#      76 print(request)
# ---> 77 return self._service.run(request)
#
# File ~/Desktop/holmes/core/service.py:32, in HolmesService.run(self, request)
#      31 def run (self, request: AnalysisRequest):
# ---> 32     analyzer = self.analyzers.get(
#      33         request.analyzer_id
#      34     )
#      35     resources = self.resources.load(
#      36         request.inputs
#      37     )
#      39     context  = AnalysisContext(
#      40         resources = resources,
#      41         params = request.params
#      42     )
#
# File ~/Desktop/holmes/core/analyzer/registry.py:24, in AnalyzerRegistry.get(self, id)
#      22     return self.items[id]
#      23 except KeyError:
# ---> 24     raise ValueError(
#      25         f"Unkown analyzer : {id}"
#      26     )
#
# ValueError: Unkown analyzer : dataset.missing_rates

# %%
# Main inspect test (rich output in Jupyter)
report = hm.inspect(sample_df)
report
# Out:
# InspectionReport(overall_health=0.66625, critical_columns=[{'column_name': 'salary', 'missing_rate': 0.8, 'missing_count': 32, 'non_missing_count': 8, 'total_count': 40}], moderate_columns=[], healthy_columns=['age', 'last_purchase_days', 'customer_id', 'country', 'segment'], full_missing_rows_rate=0.0, high_missing_rows_rate=0.0)

# %%
# Quick verification and plain-text output
report.show()

print("\nCritical columns:", [c["column_name"] for c in report.critical_columns])
print("Moderate columns:", [c["column_name"] for c in report.moderate_columns])
print("Overall health:", round(report.overall_health, 3))
# Out:
# Dataset Health Report
# ---------------------
#
# Overall Health: 0.67
#
# Critical Issue:
# - salary -> 80% missing
#
# Moderate Issues:
# - none
#
# Healthy:
# - age
# - last_purchase_days
# - customer_id
# - country
# - segment
#
# Evidence:
# - fully missing rows: 0%
# - highly missing rows (>=80% null): 0%
#
# Critical columns: ['salary']
# Moderate columns: []
# Overall health: 0.666
